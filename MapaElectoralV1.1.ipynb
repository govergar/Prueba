# %% [raw]
# Importar packages y ver como funciona con un punto cualquiera

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from geopandas.tools import sjoin
import folium
from folium.plugins import MarkerCluster
#from folium.element import IFrame
import shapely
from shapely.geometry import Point
import unicodedata
#import pysal as ps
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %% [markdown]
# Borrar las coordenadas que no se codificaron

# %%
votantes=pd.read_csv(r"C:\Users\Gonzalo\coordenadas.csv")
votantes.isnull().sum()
# Out:
# Unnamed: 0              0
# Unnamed: 0.1            0
# Unnamed: 0.1.1          0
# accuracy               15
# formatted_address      15
# google_place_id        15
# input_string            0
# latitude               15
# longitude              15
# number_of_results       0
# postcode             1971
# status                  0
# type                   15
# dtype: int64

# %% [markdown]
# Perdí 15 direcciones de 2000, Nada mal!!!!0,75%

# %%
votantes[votantes.latitude.isnull()]
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 accuracy formatted_address  \
# 278          278           278             278      NaN               NaN
# 367          367           367             367      NaN               NaN
# 404          404           404             404      NaN               NaN
# 535          535           535             535      NaN               NaN
# 577          577           577             577      NaN               NaN
# 651          651           651             651      NaN               NaN
# 758          758           758             758      NaN               NaN
# 1050        1050          1050            1050      NaN               NaN
# 1106        1106          1106            1106      NaN               NaN
# 1505        1505          1505            1505      NaN               NaN
# 1506        1506          1506            1506      NaN               NaN
# 1510        1510          1510            1510      NaN               NaN
# ...

# %%
votantes1=votantes.dropna(subset=['latitude', 'longitude'], how='all' )

# %%
coordenadas_centro=(-33.0172232,-71.5583017)
votantes2 = votantes1.sample(n=1000)

# %%
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

some_map = folium.Map(location=[-33.0172232, 
                                -71.5583017], 
                                zoom_start=18,
                                )
mc=MarkerCluster()

for row in votantes1.itertuples():
    mc.add_child(folium.Marker(location=[row.latitude,row.longitude],))
 

some_map.add_child(mc)

some_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
